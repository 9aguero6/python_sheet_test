# %% [markdown]
# <a href="https://colab.research.google.com/github/9aguero6/python_sheet_test/blob/main/Lisandra_Lab8junio2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Laboratorio Inicial 08 de junio de 2022**

# %% [markdown]
# ![sakura-card-captor.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _= default()

gc = gspread.authorize(creds)
sh = gc.create('Lisandra_Aguero_Ruiz')

# %%
worksheet = gc.open('Lisandra_Aguero_Ruiz').sheet1
cell_list = worksheet.range('A1:G14')

import random
for cell in cell_list:
  cell.value = random.randint(1,10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1x78Vl3i9O_n7z6hizOQAAZyKApT_o-dIog7JwzOHKu8',
#  'updatedCells': 98,
#  'updatedColumns': 7,
#  'updatedRange': "'Hoja 1'!A1:G14",
#  'updatedRows': 14}

# %%
worksheet = gc.open('Lisandra_Aguero_Ruiz').sheet1
rows = worksheet.get_all_values()
print(rows)
# Out:
# [['8', '9', '2', '2', '5', '8', '6'], ['2', '4', '3', '1', '9', '3', '4'], ['3', '2', '8', '1', '7', '4', '5'], ['7', '5', '10', '1', '7', '9', '8'], ['9', '9', '1', '2', '7', '7', '7'], ['3', '1', '2', '3', '8', '9', '4'], ['5', '4', '9', '5', '1', '1', '1'], ['7', '10', '8', '8', '7', '3', '7'], ['5', '8', '2', '7', '2', '4', '7'], ['10', '1', '9', '2', '1', '3', '4'], ['3', '2', '1', '8', '4', '8', '6'], ['10', '8', '4', '8', '10', '7', '10'], ['2', '4', '8', '3', '10', '4', '2'], ['6', '9', '3', '4', '1', '2', '6']]
